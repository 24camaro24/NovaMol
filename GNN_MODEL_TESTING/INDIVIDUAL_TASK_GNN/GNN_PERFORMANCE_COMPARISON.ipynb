# %%
from PerformanceInsights import *
# Out:
# Using device: cuda

# %%
run_all_gnn(dataset='CHEMBL226', properties_to_predict=['pchembl_value'])
# Out:
# --- Starting NovaMol Pipeline for Target: CHEMBL226 ---
# --- Downloading data for target CHEMBL226 from ChEMBL ---
# Downloaded and cleaned 492 unique, active compounds.
# Processed down to 492 compounds with all required properties.
# Processed analysis results saved to data/CHEMBL226_processed_analysis.csv
#
# --- 1. Preparing Data for Multi-Task GNN ---
# Creating GNN graphs: 100%|██████████| 492/492 [00:00<00:00, 2185.35it/s]
# Data split: 346 train, 72 validation, 74 test.
#
# --- Running pipeline for MultiTaskGNN_v1 ---
#
# --- 2. Training Multi-Task Predictive GNN ---
#
# GNN Epoch 01 | Validation Metrics:
# pchembl_value: MAE: 0.8428 | MSE: 1.0727 | RMSE: 1.0357 | R2: -0.0021
#
#
# GNN Epoch 02 | Validation Metrics:
# pchembl_value: MAE: 0.8634 | MSE: 1.1369 | RMSE: 1.0662 | R2: -0.0620
#
#
# GNN Epoch 03 | Validation Metrics:
# pchembl_value: MAE: 0.8411 | MSE: 1.0784 | RMSE: 1.0385 | R2: -0.0074
#
#
# GNN Epoch 04 | Validation Metrics:
# ...

# %%
run_all_gnn(dataset='CHEMBL226', properties_to_predict=['logp'])
# Out:
# --- Starting NovaMol Pipeline for Target: CHEMBL226 ---
# --- Downloading data for target CHEMBL226 from ChEMBL ---
# Downloaded and cleaned 492 unique, active compounds.
# Processed down to 492 compounds with all required properties.
# Processed analysis results saved to data/CHEMBL226_processed_analysis.csv
#
# --- 1. Preparing Data for Multi-Task GNN ---
# Creating GNN graphs: 100%|██████████| 492/492 [00:00<00:00, 2224.55it/s]
# Data split: 346 train, 72 validation, 74 test.
#
# --- Running pipeline for MultiTaskGNN_v1 ---
#
# --- 2. Training Multi-Task Predictive GNN ---
#
# GNN Epoch 01 | Validation Metrics:
# logp: MAE: 1.2974 | MSE: 3.2339 | RMSE: 1.7983 | R2: -0.0074
#
#
# GNN Epoch 02 | Validation Metrics:
# logp: MAE: 1.2996 | MSE: 3.2155 | RMSE: 1.7932 | R2: -0.0017
#
#
# GNN Epoch 03 | Validation Metrics:
# logp: MAE: 1.3149 | MSE: 3.4063 | RMSE: 1.8456 | R2: -0.0611
#
#
# GNN Epoch 04 | Validation Metrics:
# logp: MAE: 1.2865 | MSE: 3.0939 | RMSE: 1.7589 | R2: 0.0362
#
# ...

# %%
run_all_gnn(dataset='CHEMBL226', properties_to_predict=['molecular_weight'])
# Out:
# --- Starting NovaMol Pipeline for Target: CHEMBL226 ---
# --- Downloading data for target CHEMBL226 from ChEMBL ---
# Downloaded and cleaned 492 unique, active compounds.
# Processed down to 492 compounds with all required properties.
# Processed analysis results saved to data/CHEMBL226_processed_analysis.csv
#
# --- 1. Preparing Data for Multi-Task GNN ---
# Creating GNN graphs: 100%|██████████| 492/492 [00:00<00:00, 1992.85it/s]
# Data split: 346 train, 72 validation, 74 test.
#
# --- Running pipeline for MultiTaskGNN_v1 ---
#
# --- 2. Training Multi-Task Predictive GNN ---
#
# GNN Epoch 01 | Validation Metrics:
# molecular_weight: MAE: 74.0439 | MSE: 13257.2539 | RMSE: 115.1401 | R2: -0.0336
#
#
# GNN Epoch 02 | Validation Metrics:
# molecular_weight: MAE: 73.9975 | MSE: 12964.3555 | RMSE: 113.8611 | R2: -0.0108
#
#
# GNN Epoch 03 | Validation Metrics:
# molecular_weight: MAE: 74.1180 | MSE: 12875.0771 | RMSE: 113.4684 | R2: -0.0038
#
#
# GNN Epoch 04 | Validation Metrics:
# ...

# %%
run_all_gnn(dataset='CHEMBL226')
# Out:
# --- Starting NovaMol Pipeline for Target: CHEMBL226 ---
# --- Downloading data for target CHEMBL226 from ChEMBL ---
# Downloaded and cleaned 492 unique, active compounds.
# Processed down to 492 compounds with all required properties.
# Processed analysis results saved to data/CHEMBL226_processed_analysis.csv
#
# --- 1. Preparing Data for Multi-Task GNN ---
# Creating GNN graphs: 100%|██████████| 492/492 [00:00<00:00, 2017.86it/s]
# Data split: 346 train, 72 validation, 74 test.
#
# --- Running pipeline for MultiTaskGNN_v1 ---
#
# --- 2. Training Multi-Task Predictive GNN ---
#
# GNN Epoch 01 | Validation Metrics:
# pchembl_value: MAE: 0.8414 | MSE: 1.0810 | RMSE: 1.0397 | R2: -0.0098
# logp: MAE: 1.3009 | MSE: 3.2019 | RMSE: 1.7894 | R2: 0.0025
# molecular_weight: MAE: 74.8505 | MSE: 12796.0479 | RMSE: 113.1196 | R2: 0.0024
#
#
# GNN Epoch 02 | Validation Metrics:
# pchembl_value: MAE: 0.8499 | MSE: 1.1082 | RMSE: 1.0527 | R2: -0.0352
# ...
